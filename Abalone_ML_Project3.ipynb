# %% [markdown]
# # Abalone Properties
#
# Abalone is a type of mollusk that has ear-shaped shells, as well as feet and tentacles.
#
# It clings to rocks near the shores and is usually consumed by other marine species.
#
# The shell of Abalone is highly durable. Microscopic calcium carbonate builds up like bricks and is stuck together by protein layers.
#
# These proteins absorb the blows to the Abalone shell, while the calcium carbonate prevents the shells from shattering.

# %% [markdown]
# Steps following in Machine learning
#
# Data Types
#
# Display First Five Rows
#
# Missing Data
#
# Looking the Shape of Data
#
# Univariate Analysis
#
# Bivariate Analysis
#
# Data Munging
#
# Data Cleansing
#
# Hypothesis Testing
#
# Regression using ( LR, KNN, SVR, Decision Tree)

# %%
# checking the version of liabraries

# %%
# python version 

import sys
print('Python: {}'.format(sys.version))
# Out:
# Python: 3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)]

# %%
# scipy

import scipy
print('scipy: {}'.format(scipy.__version__))
# Out:
# scipy: 1.3.1

# %%
# numpy

import numpy
print('numpy: {}'.format(numpy.__version__))
# Out:
# numpy: 1.16.5

# %%
import pandas
print('pandas: {}'.format(pandas.__version__))
# Out:
# pandas: 0.25.1

# %%
# matplotlib

import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))
# Out:
# matplotlib: 3.1.1

# %%
# scikit learn

import sklearn
print('sklearn: {}'.format(sklearn.__version__))
# Out:
# sklearn: 0.21.3

# %%
# loading liabraries


import pandas as pd

import numpy as np

import seaborn as sns

from pandas.plotting import scatter_matrix

from matplotlib import pyplot

from sklearn.linear_model import LinearRegression

from sklearn import metrics

from sklearn.neighbors import KNeighborsRegressor

from sklearn.svm import SVR

from sklearn.tree import DecisionTreeRegressor

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import KFold

from sklearn.model_selection import cross_val_score

from sklearn.pipeline import Pipeline

from sklearn. preprocessing import MinMaxScaler

# %%
# import warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# loading dataset

df=pd.read_csv("abalone.csv")

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %% [markdown]
# From the dataset our target is to defined Age, for feature discription let's compute the target varible of the problem ' Age' and assigning it to the dataset. Age = Rings+1.5

# %%
# droping Rings column and adding age column of the abalone

df['Age'] = df['Rings']+1.5
df.drop('Rings', axis = 1, inplace = True)

# %%
# Lets recheck the Data shape and types

df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight   Age
# 0             0.1010        0.1500  16.5
# 1             0.0485        0.0700   8.5
# 2             0.1415        0.2100  10.5
# ...

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Age'],
#       dtype='object')

# %%
# First Five Row

df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight   Age
# 0         0.150  16.5
# 1         0.070   8.5
# 2         0.210  10.5
# 3         0.155  11.5
# 4         0.055   8.5

# %%
# Variable Identification

df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Age               float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
# Sex               4177 non-null object
# Length            4177 non-null float64
# Diameter          4177 non-null float64
# Height            4177 non-null float64
# Whole weight      4177 non-null float64
# Shucked weight    4177 non-null float64
# Viscera weight    4177 non-null float64
# Shell weight      4177 non-null float64
# Age               4177 non-null float64
# dtypes: float64(8), object(1)
# memory usage: 293.8+ KB

# %%
# null value

df.isnull()
# Out:
#         Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     False   False     False   False         False           False
# 1     False   False     False   False         False           False
# 2     False   False     False   False         False           False
# 3     False   False     False   False         False           False
# 4     False   False     False   False         False           False
# ...     ...     ...       ...     ...           ...             ...
# 4172  False   False     False   False         False           False
# 4173  False   False     False   False         False           False
# 4174  False   False     False   False         False           False
# 4175  False   False     False   False         False           False
# 4176  False   False     False   False         False           False
#
#       Viscera weight  Shell weight    Age
# 0              False         False  False
# 1              False         False  False
# ...

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Age               0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
# View points of statistical summary of the data
# data.describe() statistics figure in vertical line 
# data.describe().transpose() statistics figure in horizontal line

df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight          Age
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831    11.433684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     2.500000
# ...

# %% [markdown]
# # Univariate Analysis
# Explore one Variable at a time
#
# Summarize tha Variable
#
# Make sense out of that summary to discover insights, anomalies

# %%
# box and whisker plots

df['Age'].plot.box()

# %%
sns.distplot(df['Age'])

# %%
# histograms

df.hist(figsize=(20,20),layout=(4,2),color='green')
pyplot.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Density visualisation for all attributes

df.plot(kind='density',figsize=(20,20),layout=(4,2),sharex=False,subplots=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000007794FBC908>,
# ...
#       dtype=object)

# %%
sns.set(color_codes=True)

sns.pairplot(df,hue='Age');
pyplot.show()

# %% [markdown]
# # Evaluating Some Algorithms
#
# * Separate out a validation dataset.
#
# * Set-up the test harness to use 10-fold cross validation.
#
# * Build multiple different models to Predicting the age of abalone from physical measurements
#
# * Selecting the best model.

# %% [markdown]
# Creating a Validation Dataset
#
# split the loaded dataset into two, 80% of data which we will use to train, evaluate and select among our models, and 20% data that we will hold back as a validation dataset.

# %% [markdown]
# *  we used a python slice to select the columns in the NumPy for split out validation of data set

# %%
# Splitting the data into input and output attribute of X axis  and Y axis.

x=df.iloc[:,:-1].values
x
# Out:
# array([['M', 0.455, 0.365, ..., 0.2245, 0.10099999999999999, 0.15],
#        ['M', 0.35, 0.265, ..., 0.0995, 0.0485, 0.07],
#        ['F', 0.53, 0.42, ..., 0.2565, 0.1415, 0.21],
#        ...,
#        ['M', 0.6, 0.475, ..., 0.5255, 0.2875, 0.308],
#        ['F', 0.625, 0.485, ..., 0.531, 0.261, 0.29600000000000004],
#        ['M', 0.71, 0.555, ..., 0.9455, 0.3765, 0.495]], dtype=object)

# %%
y=df.iloc[:,-1].values
y
# Out:
# array([16.5,  8.5, 10.5, ..., 10.5, 11.5, 13.5])

# %%
# Encoding the categorical value into numerical values 

labelencoder=LabelEncoder()

x[:,0]=labelencoder.fit_transform(x[:,0])

# %%
# Splitting dataset into training and test set

train_set=0.80
test_set=0.20
seed=5

# %%
# using alogrithm

x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=train_set,test_size=test_set,random_state=seed)

# %%
x_train.shape
# Out:
# (3341, 8)

# %%
y_train.shape
# Out:
# (3341,)

# %%
x_test.shape
# Out:
# (836, 8)

# %%
y_test.shape
# Out:
# (836,)

# %% [markdown]
# # Classification Modelling
#
# * Logistic Regression (LR)
#
# * K-Nearest Neighbors (KNN).
#
# * Support Vector Regression (SVR).
#
# * Decision Tree (decision_tree).

# %%
# Check Algorithms

n_neighbors=5

models=[]

models.append(('LinearRegression',LinearRegression()))

models.append(('knn',KNeighborsRegressor(n_neighbors=n_neighbors)))

models.append(('SVR',SVR()))

models.append(("decision_tree",DecisionTreeRegressor()))

# %%
# evaluate each model in turn

results=[]

error='neg_mean_squared_error'

names=[]

for name,model in models:
    fold=KFold(n_splits=10,random_state=0)
    result=cross_val_score(model,x_train,y_train,cv=fold,scoring=error)
    results.append(result)
    names.append(name)
    ms="%s : %f (%f)"%(name,result.mean(),result.std())
    print(ms)
# Out:
# LinearRegression : -4.912809 (0.521418)
# knn : -5.065641 (0.535104)
# SVR : -5.893629 (0.704559)
# decision_tree : -8.860900 (0.836512)

# %%
# Visualizing the Model accuracy thru box plot

ma=pyplot.figure()
ma.suptitle("Comparing Algorithms")
axis=ma.add_subplot(111)
pyplot.boxplot(results)
axis.set_xticklabels(names)
pyplot.xticks(rotation='90')
pyplot.show()

# %%
# Checking and Comparing Algorithms With MinmaxScaler

pipelines=[]

pipelines.append(('scaled LinearRegression',Pipeline([('scaler',MinMaxScaler()),('LinearRegression',LinearRegression())])))

pipelines.append(('scaled KNN',Pipeline([('scaler',MinMaxScaler()),('KNN',KNeighborsRegressor(n_neighbors=n_neighbors))])))

pipelines.append(('scaled SVR',Pipeline([('scaler',MinMaxScaler()),('SVR',SVR())])))

pipelines.append(('scaled DecisionTree',Pipeline([('scaler',MinMaxScaler()),('decision',DecisionTreeRegressor())])))

# %%
# Evaluating Each model

names=[]

results2=[]

for name,model in models:
    fold=KFold(n_splits=10,random_state=0)
    result=cross_val_score(model,x_train,y_train,cv=fold,scoring=error)
    results2.append(result)
    names.append(name)
    ms2="%s : %f (%f)"%(name,result.mean(),result.std())
    print(ms2)
# Out:
# LinearRegression : -4.912809 (0.521418)
# knn : -5.065641 (0.535104)
# SVR : -5.893629 (0.704559)
# decision_tree : -9.092968 (0.661481)

# %%
# Visualizing the Model accuracy thru box plot

ma=pyplot.figure()
ma.suptitle("Comparing Algorithms")
axis=ma.add_subplot(111)
pyplot.boxplot(results2)
axis.set_xticklabels(names)
pyplot.xticks(rotation='90')
pyplot.show()

# %% [markdown]
# We can check that Algorithms we applied and cross checked with Minmaxscaller output results are different.
